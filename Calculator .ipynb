# %%
def calculate():
    try:
        
     number1= float(input("Please enter number:"))
     number2=  float(input("Please enter another number:"))            
     sign = input("Please enter a operation :")
    
     if sign== "+" :
        result=(number1+number2)
        print(f"Result : {result}" )
         
     elif sign== "-" :
         result=(number1-number2)
         print(f"Result : {result}" )

     elif sign== "*" :
         result=(number1*number2)
         print(f"Result : {result}" )
 
     elif sign== "/" :
         result=(number1/number2)
         print(f"Result : {result}" )
        
   
    except ZeroDivisionError:
         print("Division by zero is not possible.")
        
    except ValueError: 
         print("Please enter a valid number.")

# %%
calculate()
# Out:
# Please enter number: 99999999999999
# Please enter another number: 11111111111111
# Please enter a operation : +
# Result : 111111111111110.0
